# %% [markdown]
# <a href="https://colab.research.google.com/github/shibanidsai/python-basics/blob/main/List_and_Tuples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
marks = [90,92,83,56,32]

# %%
type(marks)
# Out:
# list

# %%
marks
# Out:
# [90, 92, 83, 56, 32]

# %%
len(marks)
# Out:
# 5

# %%
print(marks[0])
# Out:
# 90

# %%
print(marks[4])
# Out:
# 32

# %%
student = ["Karan", 85, 19.5, "Delhi"]

# %%
student
# Out:
# ['Karan', 85, 19.5, 'Delhi']

# %%
student[0]="Arjun"

# %%
student[1]="test"

# %%
student
# Out:
# ['Arjun', 'test', 19.5, 'Delhi']

# %%
marks
# Out:
# [90, 92, 83, 56, 32]

# %%
#slicing
marks[-1]
# Out:
# 32

# %%
marks[2:]
# Out:
# [83, 56, 32]

# %%
marks[:-2]
# Out:
# [90, 92, 83]

# %%
marks[1:]
# Out:
# [92, 83, 56, 32]

# %%
#Essential List Methods
sample_list=[2,1,3]
#demonstrating the none trap
result=sample_list.append(4)

# %%
sample_list
# Out:
# [2, 1, 3, 4]

# %%
sample_list
# Out:
# [2, 1, 3, 4]

# %%
result

# %%
type(result)
# Out:
# NoneType

# %%
sample_list.sort()

# %%
sample_list
# Out:
# [1, 2, 3, 4]

# %%
sample_list.sort(reverse=True)

# %%
sample_list
# Out:
# [13, 27, 27, 1, 13]

# %%
sample_list.insert(4,27) #we specify index and value we want to inser to that index

# %%
sample_list.reverse()

# %%
sample_list.remove(13)

# %%
sample_list.pop(0)
# Out:
# 4

# %%
###Tuples

# %%
my_tuple = (87, 64, 33, 95,33,56)

# %%
my_tuple[0]
# Out:
# 87

# %%
my_tuple[0]=43
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_383/925053171.py in <cell line: 0>()
# ----> 1 my_tuple[0]=43
#
# TypeError: 'tuple' object does not support item assignment

# %%
tup_correct=(1,)

# %%
type(tup_correct)
# Out:
# tuple

# %%
tup_wrong=(1)

# %%
type(tup_wrong)
# Out:
# int

# %%
#Methods in Tuples
my_tuple.index(33)
# Out:
# 2

# %%
my_tuple.count(33)
# Out:
# 2

# %%
#Capture three user inputs and store them in list

movies=[]

for i in range(3):
    user_input=input("Enter a movie you like: ")
    movies.append(user_input)

movies # out of for loop to print the list
# Out:
# Enter a movie you like: a
# Enter a movie you like: b
# Enter a movie you like: c
# ['a', 'b', 'c']

# %%
#Palindrome check
user_input=[]
user_input=input("Enter a  odd numberstring: ")
# if user_input==user_input[::-1]: 2 ways
if user_input==user_input.reverse()
    print("This is a palindrome")
else:
    print("This is not a palindrome")
# Out:
# Enter a  odd numberstring: 12321
# This is a palindrome

# %%
#Grade Analysis
#Count "A" grades in a tuple and then sort the data.
grade_tuple = ("C", "D", "A", "A", "B", "B", "A")

grade_tuple.count("A")
# Out:
# 3

# %%
grade_tuple=list(grade_tuple)

# %%
grade_tuple.sort()

# %%
print(grade_tuple)
# Out:
# ['A', 'A', 'A', 'B', 'B', 'C', 'D']
